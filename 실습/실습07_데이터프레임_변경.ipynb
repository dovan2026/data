# %% [markdown]
# # 데이터프레임 변경

# %% [markdown]
# 1) pandas 라이브러리를 불러오세요.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2) 다음 파일을 읽어 titanic 데이터프레임을 만드세요.
#
# - 파일 : 'titanic_train.csv'

# %% [markdown]
# **[titanic 데이터 셋 정보]**
#
# - Survived: 생존여부(1=Yes, 0=No)
# - Pclass: 객실등급(1=1st, 2=2nd, 3=3rd)
# - Sex: 성별(male, female)
# - Age: 나이
# - Sibsp: 탑승한 형제자매, 배우자 수
# - Parch: 탑승한 자녀, 부모 수
# - Ticket: 티켓 번호
# - Fare: 요금
# - Cabin: 캐빈 번호
# - Embarked: 출발한 항구((C=Cherbourg, Q=Queenstown, S=Southampton)

# %%
path = '../실습_data/titanic_train.csv'
ttc = pd.read_csv(path)

ttc
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# 3) 상위 5개 행을 확인하세요.

# %%
ttc.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 4) 다음 요구사항에 맞게 순서대로 구문을 작성하고 확인하세요.
#
# - 4-1) PassengerId, Name, Ticket, Cabin 열을 한 번에 삭제하세요.
# - 4-2) Sex 열 이름을 Male로 변경하세요.
# - 4-3) Male 열 값을 'male'은 1, 'female'은 0으로 변경하세요.
# - 4-4) SibSp 열과 Parch 열의 값을 더한 결과를 갖는 Family 열을 추가하세요.
# - 4-5) SibSp, Parch 두 열을 삭제하세요.
# - 4-6) 결과를 확인하세요.

# %%
# 4-1 PassengerId, Name, Ticket, Cabin 열을 한 번에 삭제하세요.
ttc.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
ttc
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
# 4-2 Sex 열 이름을 Male로 변경하세요.
ttc = ttc.rename(columns={'Sex': 'Male'})
ttc
# Out:
#      Survived  Pclass    Male   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
# 4-3 Male 열 값을 'male'은 1, 'female'은 0으로 변경하세요.
ttc['Male'] = ttc['Male'].map({'male':1, 'female':0})
ttc
# Out:
#      Survived  Pclass  Male   Age  SibSp  Parch     Fare Embarked
# 0           0       3     1  22.0      1      0   7.2500        S
# 1           1       1     0  38.0      1      0  71.2833        C
# 2           1       3     0  26.0      0      0   7.9250        S
# 3           1       1     0  35.0      1      0  53.1000        S
# 4           0       3     1  35.0      0      0   8.0500        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 886         0       2     1  27.0      0      0  13.0000        S
# 887         1       1     0  19.0      0      0  30.0000        S
# 888         0       3     0   NaN      1      2  23.4500        S
# 889         1       1     1  26.0      0      0  30.0000        C
# 890         0       3     1  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
# 4-4) SibSp 열과 Parch 열의 값을 더한 결과를 갖는 Family 열을 추가하세요.
ttc['Family'] = ttc['SibSp'] + ttc['Parch']
ttc
# Out:
#      Survived  Pclass  Male   Age  SibSp  Parch     Fare Embarked  Family
# 0           0       3     1  22.0      1      0   7.2500        S       1
# 1           1       1     0  38.0      1      0  71.2833        C       1
# 2           1       3     0  26.0      0      0   7.9250        S       0
# 3           1       1     0  35.0      1      0  53.1000        S       1
# 4           0       3     1  35.0      0      0   8.0500        S       0
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 886         0       2     1  27.0      0      0  13.0000        S       0
# 887         1       1     0  19.0      0      0  30.0000        S       0
# 888         0       3     0   NaN      1      2  23.4500        S       3
# 889         1       1     1  26.0      0      0  30.0000        C       0
# 890         0       3     1  32.0      0      0   7.7500        Q       0
#
# [891 rows x 9 columns]

# %%
# 4-5) SibSp, Parch 두 열을 삭제하세요.
ttc.drop(['SibSp','Parch'],axis=1, inplace=True)
ttc
# Out:
#      Survived  Pclass  Male   Age     Fare Embarked  Family
# 0           0       3     1  22.0   7.2500        S       1
# 1           1       1     0  38.0  71.2833        C       1
# 2           1       3     0  26.0   7.9250        S       0
# 3           1       1     0  35.0  53.1000        S       1
# 4           0       3     1  35.0   8.0500        S       0
# ..        ...     ...   ...   ...      ...      ...     ...
# 886         0       2     1  27.0  13.0000        S       0
# 887         1       1     0  19.0  30.0000        S       0
# 888         0       3     0   NaN  23.4500        S       3
# 889         1       1     1  26.0  30.0000        C       0
# 890         0       3     1  32.0   7.7500        Q       0
#
# [891 rows x 7 columns]

# %%
# 4-6) 결과를 확인하세요.
ttc.head()
# Out:
#    Survived  Pclass  Male   Age     Fare Embarked  Family
# 0         0       3     1  22.0   7.2500        S       1
# 1         1       1     0  38.0  71.2833        C       1
# 2         1       3     0  26.0   7.9250        S       0
# 3         1       1     0  35.0  53.1000        S       1
# 4         0       3     1  35.0   8.0500        S       0

# %% [markdown]
# 5) 다음 요구사항에 맞게 순서대로 구문을 작성하고 확인하세요.
#
# - 5-1) 기초통계량에서 Age 열의 25%, 50%, 75% 값을 조회해 q1, q2, q3 변수를 선언하세요.
# - 5-2) 아래 범위와 값을 참조해 'a' ~ 'd' 값을 갖는 AgeGrp 열을 추가하세요.
#     - q1 이하 → 'a'
#     - q1 초과 q2 이하 → 'b'
#     - q2 초과 q3 이하 → 'c'
#     - q3 초과 → 'd'
# - 5-3) AgeGrp 별 생존율을 집계하여 tmp 데이터프레임을 선언하세요.
# - 5-4) tmp 데이터프레임을 막대그래프로 시각화해 확인하세요.

# %%
# 5-1) 기초통계량에서 Age 열의 25%, 50%, 75% 값을 조회해 q1, q2, q3 변수를 선언하세요.
q1 = ttc['Age'].describe()['25%']
q2 = ttc['Age'].describe()['50%']
q3 = ttc['Age'].describe()['75%']

print(q1, q2, q3)
# Out:
# 20.125 28.0 38.0

# %%
# 5-2) 아래 범위와 값을 참조해 'a' ~ 'd' 값을 갖는 AgeGrp 열을 추가하세요.
# q1 이하 → 'a'
# q1 초과 q2 이하 → 'b'
# q2 초과 q3 이하 → 'c'
# q3 초과 → 'd'
my_bin = [-np.inf, q1, q2, q3, np.inf]
my_label = list('abcd')

ttc['AgeGrp'] = pd.cut(ttc['Age'], bins=my_bin, labels=my_label)
ttc.value_counts()
# Out:
# Survived  Pclass  Male  Age   Fare     Embarked  Family  AgeGrp
# 0         2       1     25.0  13.0000  S         0       b         3
#           3       1     17.0  8.6625   S         0       a         3
#           2       1     30.0  13.0000  S         0       c         3
#           3       1     19.0  7.8958   S         0       a         3
#           2       1     23.0  13.0000  S         0       b         3
#                                                                   ..
# 1         1       1     26.0  30.0000  C         0       d         0
#                                                          a         0
# 0         3       1     32.0  7.7500   Q         0       b         0
#                                                          d         0
#                                                          a         0
# Name: count, Length: 2696, dtype: int64

# %%
# 5-3) AgeGrp 별 생존율을 집계하여 tmp 데이터프레임을 선언하세요.
tmp = ttc.groupby(by=['AgeGrp'], as_index=False)[['Survived']].mean()
tmp
# Out:
#   AgeGrp  Survived
# 0      a  0.458101
# 1      b  0.360656
# 2      c  0.434286
# 3      d  0.372881

# %%
# 5-4) tmp 데이터프레임을 막대그래프로 시각화해 확인하세요.
tmp.plot(kind='bar')
# Out:
# <Axes: >
